# %%
import sys
from pathlib import Path

## get the python versiom

python_version = sys.version_info

python_version # return python version in tuple
python_env = sys.executable

# %%
print(f"Python version major : {python_version[0]} and minor : {python_version[1]} and micro : {python_version[2]}")
print(f"The python exceutable path is : {python_env}")
# Out:
# Python version major : 3 and minor : 12 and micro : 12
# The python exceutable path is : /Users/sachin/Desktop/arxiv-paper-curator/.venv/bin/python

# %%
(10,21) > (10,20)
# Out:
# True

# %%
from pathlib import Path

current_working_dir = Path.cwd()
current_working_dir
# Out:
# PosixPath('/Users/sachin/Desktop/arxiv-paper-curator/notebooks/week1')

# %%
current_working_dir.parent.parent
# Out:
# PosixPath('/Users/sachin/Desktop/arxiv-paper-curator')
